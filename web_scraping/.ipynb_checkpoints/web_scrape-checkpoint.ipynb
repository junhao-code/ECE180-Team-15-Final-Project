# %%
import urllib2
from bs4 import BeautifulSoup
import csv
import pandas as pd
# What year?
year = 2011
m = 2
d = 27
date = str(year)+ str(m) + str(d)
# Create/open a file called wunder.txt
#f = open('/Users/supersu/Desktop/wunder-data-' + str(year), 'w')
f = open('wunder-data-'+str(year), 'w')
f.write('datestamp,tmean,tmax,tmin,precip,dewpoint\n')

# Iterate through months and days
# for m in range(1, 13):
#     for d in range(1, 32):

#         # Check if already gone through month
#         if (m == 2 and d > 28):
#             break
#         elif (m in [4, 6, 9, 11] and d > 30):
#             break

# Open wunderground.com url
datestamp = str(year) + '-' + str(m) + '-' + str(d)
print 'Getting data for ' + datestamp
#         url = 'http://www.wunderground.com/history/airport/KNYC/' + str(year) + '/' + str(m) + '/' + str(d) + '/DailyHistory.html'
url = 'http://www.wunderground.com/history/airport/KNYC/'+ str(year)+ '/' + str(m) + '/' + str(d) +'/DailyHistory.html'
page = urllib2.urlopen(url)

# Get  table
soup = BeautifulSoup(page, "lxml")
table = soup.find_all('table', attrs={'class' : "obs-table"})
# print table
headers = [header.text for header in table[0].find_all('th')]
# print headers
rows = [headers]
for row in table[0].find_all('tr'):
    cur = []
#     print type(row)
    for val in row.find_all('td'):
        temp = str(val.text.encode("UTF-8"))
        temp = temp.strip('\n')
        cur.append(temp)
    rows.append(cur)
#         print 'val type is' + str(type(val.text))
#        str(val.text).replace("\xc2\xa0","")
#         text = val.decode("UTF-8")
#         print text
#         text.replace("\xc2\xa0", " ")
#        cur.append(val.text.encode("UTF-8"))
print rows

my_df = pd.DataFrame(rows)   
my_df.to_csv('weather_'+date+'.csv', index=False, header=False)

#with open("out4.csv", "wb") as f:
#    wr = csv.writer(f)
#    wr.writerow(headers)
#    wr.writerows([[td.text.encode("UTF-8") for td in row.find_all("td")] for row in table[0].select("tr + tr")])

# spans = table[0].find_all(attrs={'class':'nobr'})
# print spans

#         # Get mean temperatures from page
#         tmean = spans[0].span.string
#         tmax = spans[2].span.string
#         tmin = spans[5].span.string

#         #Get precip from page
#         precip = spans[9].span.string

#         #Get dewpoint from page
#         dewpoint = spans[8].span.string
 
#         # Format month for datestamp
#         if len(str(m)) < 2:
#             mStamp = '0' + str(m)
#         else:
#             mStamp = str(m)

#         # Format day for datestamp
#         if len(str(d)) < 2:
#             dStamp = '0' + str(d)
#         else:
#             dStamp = str(d)

#         # Build timestamp
#         datestamp = str(year) + mStamp + dStamp

#         # Write timestamp and temperature to file
#         print tmean + ':' + tmax + ':' + tmax + ':' + precip + ':' + dewpoint
#         f.write(datestamp + ',' + tmean + ',' + tmax + ',' + tmin + ',' + precip + ',' + dewpoint + '\n')

# Done getting data! Close file.
#f.close()
# Out:
# Getting data for 2011-2-27
# [[u'Time (EST)', u'Temp.', u'Windchill', u'Dew Point', u'Humidity', u'Pressure', u'Visibility', u'Wind Dir', u'Wind Speed', u'Gust Speed', u'Precip', u'Events', u'Conditions'], [], ['12:51 AM', '39.0\xc2\xa0\xc2\xb0F', '33.4\xc2\xa0\xc2\xb0F', '28.9\xc2\xa0\xc2\xb0F', '67%', '29.94\xc2\xa0in', '10.0\xc2\xa0mi', 'South', '8.1\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['1:51 AM', '39.0\xc2\xa0\xc2\xb0F', '34.0\xc2\xa0\xc2\xb0F', '30.9\xc2\xa0\xc2\xb0F', '73%', '29.91\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '6.9\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['2:34 AM', '39.2\xc2\xa0\xc2\xb0F', '32.5\xc2\xa0\xc2\xb0F', '32.0\xc2\xa0\xc2\xb0F', '75%', '29.91\xc2\xa0in', '10.0\xc2\xa0mi', 'SSE', '10.4\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['2:51 AM', '39.0\xc2\xa0\xc2\xb0F', '36.8\xc2\xa0\xc2\xb0F', '32.0\xc2\xa0\xc2\xb0F', '76%', '29.88\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '3.5\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['3:51 AM', '39.0\xc2\xa0\xc2\xb0F', '36.8\xc2\xa0\xc2\xb0F', '34.0\xc2\xa0\xc2\xb0F', '82%', '29.87\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '3.5\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['4:51 AM', '39.9\xc2\xa0\xc2\xb0F', '36.7\xc2\xa0\xc2\xb0F', '35.1\xc2\xa0\xc2\xb0F', '83%', '29.87\xc2\xa0in', '9.0\xc2\xa0mi', 'Variable', '4.6\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['5:24 AM', '39.2\xc2\xa0\xc2\xb0F', '37.0\xc2\xa0\xc2\xb0F', '33.8\xc2\xa0\xc2\xb0F', '81%', '29.91\xc2\xa0in', '9.0\xc2\xa0mi', 'Variable', '3.5\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['5:47 AM', '39.2\xc2\xa0\xc2\xb0F', '35.0\xc2\xa0\xc2\xb0F', '33.8\xc2\xa0\xc2\xb0F', '81%', '29.91\xc2\xa0in', '9.0\xc2\xa0mi', 'Variable', '5.8\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['5:51 AM', '39.0\xc2\xa0\xc2\xb0F', '36.8\xc2\xa0\xc2\xb0F', '33.1\xc2\xa0\xc2\xb0F', '79%', '29.88\xc2\xa0in', '9.0\xc2\xa0mi', 'Variable', '3.5\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Overcast'], ['6:42 AM', '39.2\xc2\xa0\xc2\xb0F', '34.2\xc2\xa0\xc2\xb0F', '33.8\xc2\xa0\xc2\xb0F', '81%', '29.92\xc2\xa0in', '9.0\xc2\xa0mi', 'Variable', '6.9\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Mostly Cloudy'], ['6:51 AM', '39.0\xc2\xa0\xc2\xb0F', '34.0\xc2\xa0\xc2\xb0F', '32.0\xc2\xa0\xc2\xb0F', '76%', '29.90\xc2\xa0in', '8.0\xc2\xa0mi', 'West', '6.9\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Mostly Cloudy'], ['7:51 AM', '39.0\xc2\xa0\xc2\xb0F', '32.8\xc2\xa0\xc2\xb0F', '30.0\xc2\xa0\xc2\xb0F', '70%', '29.94\xc2\xa0in', '10.0\xc2\xa0mi', 'West', '9.2\xc2\xa0mph', '17.3\xc2\xa0mph', 'N/A', '\t\xc2\xa0', 'Clear'], ['8:51 AM', '41.0\xc2\xa0\xc2\xb0F', '35.2\xc2\xa0\xc2\xb0F', '30.0\xc2\xa0\xc2\xb0F', '65%', '29.96\xc2\xa0in', '10.0\xc2\xa0mi', 'West', '9.2\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Clear'], ['9:51 AM', '43.0\xc2\xa0\xc2\xb0F', '38.2\xc2\xa0\xc2\xb0F', '28.0\xc2\xa0\xc2\xb0F', '56%', '29.97\xc2\xa0in', '10.0\xc2\xa0mi', 'West', '8.1\xc2\xa0mph', '20.7\xc2\xa0mph', 'N/A', '\t\xc2\xa0', 'Scattered Clouds'], ['10:51 AM', '44.1\xc2\xa0\xc2\xb0F', '38.6\xc2\xa0\xc2\xb0F', '25.0\xc2\xa0\xc2\xb0F', '47%', '29.98\xc2\xa0in', '10.0\xc2\xa0mi', 'NW', '10.4\xc2\xa0mph', '19.6\xc2\xa0mph', 'N/A', '\t\xc2\xa0', 'Clear'], ['11:51 AM', '46.0\xc2\xa0\xc2\xb0F', '42.5\xc2\xa0\xc2\xb0F', '25.0\xc2\xa0\xc2\xb0F', '44%', '30.00\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '6.9\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Clear'], ['12:51 PM', '48.0\xc2\xa0\xc2\xb0F', '  -', '24.1\xc2\xa0\xc2\xb0F', '39%', '29.98\xc2\xa0in', '10.0\xc2\xa0mi', 'WNW', '9.2\xc2\xa0mph', '16.1\xc2\xa0mph', 'N/A', '\t\xc2\xa0', 'Clear'], ['1:51 PM', '48.0\xc2\xa0\xc2\xb0F', '  -', '23.0\xc2\xa0\xc2\xb0F', '37%', '29.98\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '6.9\xc2\xa0mph', '  -', 'N/A', '\t\xc2\xa0', 'Mostly Cloudy'], ['2:51 PM', '50.0\xc2\xa0\xc2\xb0F', '  -', '23.0\xc2\xa0\xc2\xb0F', '35%', '29.99\xc2\xa0in', '10.0\xc2\xa0mi', 'Variable', '5.8\xc2\xa0mph', '16.1\xc2\xa0mph', 'N/A', '\t\xc2\xa0', 'Clear'], ['3:5 ...
